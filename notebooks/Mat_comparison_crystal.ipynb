# %%
import os, io
import glob
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import pywt

# %%
file_paths = glob.glob("../results/**/**/*.csv", recursive = True)

for idx, file in enumerate(file_paths):
    print(idx, file)
# Out:
# 0 ../results\AL7075T6-20250331\Al7075T6_20250331_001\Al7075T6_20250331_001_secondary_data.csv
# 1 ../results\AL7075T6-20250331\Al7075T6_20250331_001\Al7075T6_20250331_001_primary_data.csv
# 2 ../results\AL7075T6-20250331\Al7075T6_20250331_002\Al7075T6_20250331_002_secondary_data.csv
# 3 ../results\AL7075T6-20250331\Al7075T6_20250331_002\Al7075T6_20250331_002_primary_data.csv
# 4 ../results\AL7075T6-20250331\Al7075T6_20250331_003\Al7075T6_20250331_003_secondary_data.csv
# 5 ../results\AL7075T6-20250331\Al7075T6_20250331_003\Al7075T6_20250331_003_primary_data.csv
# 6 ../results\AL7075T6-20250331\Al7075T6_20250331_004\Al7075T6_20250331_004_secondary_data.csv
# 7 ../results\AL7075T6-20250331\Al7075T6_20250331_004\Al7075T6_20250331_004_primary_data.csv
# 8 ../results\AL7075T6-20250331\Al7075T6_20250331_005\Al7075T6_20250331_005_secondary_data.csv
# 9 ../results\AL7075T6-20250331\Al7075T6_20250331_005\Al7075T6_20250331_005_primary_data.csv
# 10 ../results\AL7075T6-20250331\Al7075T6_20250331_006\Al7075T6_20250331_006_secondary_data.csv
# 11 ../results\AL7075T6-20250331\Al7075T6_20250331_006\Al7075T6_20250331_006_primary_data.csv
# 12 ../results\AL7075T6-20250331\Al7075T6_20250331_007\Al7075T6_20250331_007_secondary_data.csv
# 13 ../results\AL7075T6-20250331\Al7075T6_20250331_007\Al7075T6_20250331_007_primary_data.csv
# 14 ../results\AL7075T6-20250331\Al7075T6_20250331_008\Al7075T6_20250331_008_secondary_data.csv
# 15 ../results\AL7075T6-20250331\Al7075T6_20250331_008\Al7075T6_20250331_008_primary_data.csv
# 16 ../results\ST1018_005\ST1018_005_secondary_data.csv
# 17 ../results\ST1018_005\ST1018_005_primary_data.csv
# 18 ../results\ST1018_006\ST1018_006_secondary_data.csv
# 19 ../results\ST1018_006\ST1018_006_primary_data.csv
# 20 ../results\Elastic\Elastic_001_primary_data.csv
# 21 ../results\Elastic\Elastic_002_primary_data.csv
# 22 ../results\Elastic\Elastic_003_primary_data.csv
# 23 ../results\Elastic\Elastic_004_primary_data.csv
# 24 ../results\Elastic\Elastic_005_primary_data.csv
# 25 ../results\Elastic\Elastic_006_primary_data.csv
# 26 ../results\Elastic\Elastic_007_primary_data.csv
# 27 ../results\Elastic\Elastic_008_primary_data.csv
# 28 ../results\Elastic\Elastic_009_primary_data.csv
# 29 ../results\Elastic\Elastic_010_primary_data.csv
# 30 ../results\Elastic\Elastic_011_primary_data.csv
# 31 ../results\Elastic\Elastic_012_primary_data.csv
# 32 ../results\Elastic\Elastic_019\Elastic_019_primary_data.csv
# 33 ../results\Elastic\Elastic_020\Elastic_020_primary_data.csv
# 34 ../results\Elastic\Elastic_021\Elastic_021_primary_data.csv
# 35 ../results\ST_1018\ST1018_008\ST1018_008_secondary_data.csv
# 36 ../results\ST_1018\ST1018_007\ST1018_007_secondary_data.csv
# 37 ../results\ST_1018\ST1018_009\ST1018_009_primary_data.csv
# 38 ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# 118 ../results\Elastic\Elastic_007_primary_data.csv
# 119 ../results\Elastic\Elastic_008_primary_data.csv
# 120 ../results\Elastic\Elastic_009_primary_data.csv
# 121 ../results\Elastic\Elastic_010_primary_data.csv
# 122 ../results\Elastic\Elastic_011_primary_data.csv
# 123 ../results\Elastic\Elastic_012_primary_data.csv
# 124 ../results\Elastic\Elastic_019\Elastic_019_primary_data.csv
# 125 ../results\Elastic\Elastic_020\Elastic_020_primary_data.csv
# 126 ../results\Elastic\Elastic_021\Elastic_021_primary_data.csv
# 127 ../results\Elastic\Elastic_019\Elastic_019_primary_data.csv
# 128 ../results\Elastic\Elastic_020\Elastic_020_primary_data.csv
# 129 ../results\Elastic\Elastic_021\Elastic_021_primary_data.csv
# 130 ../results\ST_1018\ST1018_008\ST1018_008_secondary_data.csv
# 131 ../results\ST_1018\ST1018_007\ST1018_007_secondary_data.csv
# 132 ../results\ST_1018\ST1018_009\ST1018_009_primary_data.csv
# 133 ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# 134 ../results\ST_1018\ST1018_010\ST1018_010_primary_data.csv
# 135 ../results\ST_1018\ST1018_010\ST1018_010_secondary_data.csv
# 136 ../results\ST_1018\ST1018_011\ST1018_011_primary_data.csv
# 137 ../results\ST_1018\ST1018_011\ST1018_011_secondary_data.csv
# 138 ../results\ST_1018\ST1018_012\ST1018_012_primary_data.csv
# 139 ../results\ST_1018\ST1018_012\ST1018_012_secondary_data.csv
# 140 ../results\ST_1018\ST1018_008\ST1018_008_secondary_data.csv
# 141 ../results\ST_1018\ST1018_007\ST1018_007_secondary_data.csv
# 142 ../results\ST_1018\ST1018_009\ST1018_009_primary_data.csv
# 143 ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# 144 ../results\ST_1018\ST1018_010\ST1018_010_primary_data.csv
# 145 ../results\ST_1018\ST1018_010\ST1018_010_secondary_data.csv
# 146 ../results\ST_1018\ST1018_011\ST1018_011_primary_data.csv
# 147 ../results\ST_1018\ST1018_011\ST1018_011_secondary_data.csv
# 148 ../results\ST_1018\ST1018_012\ST1018_012_primary_data.csv
# 149 ../results\ST_1018\ST1018_012\ST1018_012_secondary_data.csv
# 150 ../results\SS316_Mono\SS316_002\SS316_002_primary_data.csv
# 151 ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# 152 ../results\SS316_Mono\SS316_003\SS316_003_primary_data.csv
# 153 ../results\SS316_Mono\SS316_003\SS316_003_secondary_data.csv
# 154 ../results\SS316_Mono\SS316_004\SS316_004_primary_data.csv
# 155 ../results\SS316_Mono\SS316_004\SS316_004_secondary_data.csv
# 156 ../results\SS316_Mono\SS316_006\SS316_006_primary_data.csv
# 157 ../results\SS316_Mono\SS316_006\SS316_006_secondary_data.csv
# 158 ../results\SS316_Mono\SS316_007\SS316_007_secondary_data.csv
# 159 ../results\SS316_Mono\SS316_008\SS316_008_primary_data.csv
# 160 ../results\SS316_Mono\SS316_008\SS316_008_secondary_data.csv
# 161 ../results\SS316_Mono\SS316_005\SS316_005_primary_data.csv
# 162 ../results\SS316_Mono\SS316_005\SS316_005_secondary_data.csv
# 163 ../results\SS316_Mono\SS316_002\SS316_002_primary_data.csv
# 164 ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# 165 ../results\SS316_Mono\SS316_003\SS316_003_primary_data.csv
# 166 ../results\SS316_Mono\SS316_003\SS316_003_secondary_data.csv
# 167 ../results\SS316_Mono\SS316_004\SS316_004_primary_data.csv
# 168 ../results\SS316_Mono\SS316_004\SS316_004_secondary_data.csv
# 169 ../results\SS316_Mono\SS316_006\SS316_006_primary_data.csv
# 170 ../results\SS316_Mono\SS316_006\SS316_006_secondary_data.csv
# 171 ../results\SS316_Mono\SS316_007\SS316_007_secondary_data.csv
# 172 ../results\SS316_Mono\SS316_008\SS316_008_primary_data.csv
# 173 ../results\SS316_Mono\SS316_008\SS316_008_secondary_data.csv
# 174 ../results\SS316_Mono\SS316_005\SS316_005_primary_data.csv
# 175 ../results\SS316_Mono\SS316_005\SS316_005_secondary_data.csv
# 176 ../results\A356\A356_001\A356_001_primary_data.csv
# 177 ../results\A356\A356_001\A356_001_secondary_data.csv
# 178 ../results\A356\A356_002\A356_002_primary_data.csv
# 179 ../results\A356\A356_002\A356_002_secondary_data.csv
# 180 ../results\A356\A356_001\A356_001_primary_data.csv
# 181 ../results\A356\A356_001\A356_001_secondary_data.csv
# 182 ../results\A356\A356_002\A356_002_primary_data.csv
# 183 ../results\A356\A356_002\A356_002_secondary_data.csv
# 184 ../results\AL7075T6\AL7075T6_010\AL7075T6_010_primary_data.csv
# 185 ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# 186 ../results\AL7075T6\AL7075T6_011\AL7075T6_011_primary_data.csv
# 187 ../results\AL7075T6\AL7075T6_011\AL7075T6_011_secondary_data.csv
# 188 ../results\AL7075T6\AL7075T6_010\AL7075T6_010_primary_data.csv
# 189 ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# 190 ../results\AL7075T6\AL7075T6_011\AL7075T6_011_primary_data.csv
# 191 ../results\AL7075T6\AL7075T6_011\AL7075T6_011_secondary_data.csv
# 192 ../results\SS316_3D\SS316_009\SS316_009_primary_data.csv
# 193 ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# 194 ../results\SS316_3D\SS316_010\SS316_010_primary_data.csv
# 195 ../results\SS316_3D\SS316_010\SS316_010_secondary_data.csv
# 196 ../results\SS316_3D\SS316_009\SS316_009_primary_data.csv
# 197 ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# 198 ../results\SS316_3D\SS316_010\SS316_010_primary_data.csv
# 199 ../results\SS316_3D\SS316_010\SS316_010_secondary_data.csv
# 200 ../results\Composites\SS316A356_001\SS316A356_001_primary_data.csv
# 201 ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv
# 202 ../results\Composites\SS316A356_002\SS316A356_002_primary_data.csv
# 203 ../results\Composites\SS316A356_002\SS316A356_002_secondary_data.csv
# 204 ../results\Composites\SS316A356_003\SS316A356_003_primary_data.csv
# 205 ../results\Composites\SS316A356_003\SS316A356_003_secondary_data.csv
# 206 ../results\Composites\SS316A356_001\SS316A356_001_primary_data.csv
# 207 ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv
# 208 ../results\Composites\SS316A356_002\SS316A356_002_primary_data.csv
# 209 ../results\Composites\SS316A356_002\SS316A356_002_secondary_data.csv
# 210 ../results\Composites\SS316A356_003\SS316A356_003_primary_data.csv
# 211 ../results\Composites\SS316A356_003\SS316A356_003_secondary_data.csv

# %%
legends = ["AL-7075T6","A356","1018 ST", "316SS", "316SS 3D Printed","SS316 - A356 Composite"]
selected = [file_paths[i] for i in [ 189, 61, 38, 46, 67, 201]]
#line_mode = ["solid", "longdash", "dashdot"]
line_mode = ["solid", "longdash", "dot", "dashdot", "dash", "solid"]
color = ["blue", "blue", "red", "red", "red", "orange"]


fig_path = "../results/mat_crystal_comparison"
os.makedirs(fig_path, exist_ok=True)

file_paths[67]
# Out:
# '../results\\SS316_3D\\SS316_009\\SS316_009_secondary_data.csv'

# %%
stress_strain_fig = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Engineering Strain 3W"]
    stress_1w = data["Engineering Stress 1W"]
    #stress_2w = data["Engineering Stress 2W"]

    stress_strain_fig.add_trace(go.Scatter(x=-strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    #stress_strain_fig.add_trace(go.Scatter(x=-strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]} 2W", 
                                                        #line=dict(width=3, dash="longdash", color=color[idx])))

    # Customize layout
stress_strain_fig.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="Engineering Stress vs Strain", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Strain (mm/mm)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Stress (MPa)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=16, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

stress_strain_fig.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
stress_strain_fig.write_html(os.path.join(fig_path, "Eng_Stress_strain_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
true_stress_strain_fig = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    print(data.columns)

    strain = data["True Strain 3W"]
    stress_1w = data["Engineering Stress 1W"] * (1 + data["True Strain 3W"] )
    #stress_2w = data["Engineering Stress 2W"] * (1 + data["True Strain 3W"] )

    true_stress_strain_fig.add_trace(go.Scatter(x=-strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    #true_stress_strain_fig.add_trace(go.Scatter(x=-strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]} 2W", 
                                                        #line=dict(width=3, dash="longdash", color=color[idx])))

    # Customize layout
true_stress_strain_fig.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="True Stress vs Strain", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="True Strain (mm/mm)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="True Stress (MPa)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=16, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

true_stress_strain_fig.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=14, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
true_stress_strain_fig.write_html(os.path.join(fig_path, "True_Stress_strain_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')
# ../results\A356\A356_002\A356_002_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv
# Index(['Time', 'Incident', 'Reflected', 'Transmitted', 'Front Displacement',
#        'Back Displacement', 'Front Force', 'Back Force', 'Strain Rate 3W',
#        'Strain Rate 1W', 'Engineering Strain 3W', 'Engineering Strain 1W',
#        'Engineering Stress 2W', 'Engineering Stress 1W', 'True Strain 3W',
#        'True Strain 1W', 'True Stress 2W', 'True Stress 1W'],
#       dtype='object')

# %%
eng_strain_rate = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['Strain Rate 3W']
    stress_2w = data['Strain Rate 3W']

    eng_strain_rate.add_trace(go.Scatter(x=strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    #eng_strain_rate.add_trace(go.Scatter(x=strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]} 3W", 
                                                        #line=dict(width=3, dash="longdash", color=color[idx])))
    # Customize layout
eng_strain_rate.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="Strain Rate vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Strain Rate (1/s)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=20, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

eng_strain_rate.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=14, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
eng_strain_rate.write_html(os.path.join(fig_path, "eng_strain_rate_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
eng_strain = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['Engineering Strain 1W']
    stress_2w = data['Engineering Strain 3W']

    #eng_strain.add_trace(go.Scatter(x=strain, y=stress_1w, mode='lines', name=f"{legends[idx]} 1w", 
                                                        #line=dict(width=3, dash="solid", color=color[idx])))
    eng_strain.add_trace(go.Scatter(x=strain, y=-stress_2w, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    # Customize layout
eng_strain.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="Engineering Strain vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Strain (mm/mm)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=20, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

eng_strain.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
eng_strain.write_html(os.path.join(fig_path, "eng_strain_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
eng_strain = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['Engineering Strain 1W']
    stress_2w = np.log(1 + data['Engineering Strain 3W'])

    #eng_strain.add_trace(go.Scatter(x=strain, y=stress_1w, mode='lines', name=f"{legends[idx]} 1w", 
                                                        #line=dict(width=3, dash="solid", color=color[idx])))
    eng_strain.add_trace(go.Scatter(x=strain, y=-stress_2w, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    # Customize layout
eng_strain.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="True Strain vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Strain (mm/mm)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=20, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

eng_strain.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
eng_strain.write_html(os.path.join(fig_path, "true_strain_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
eng_stress = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['Engineering Stress 1W']
    stress_2w = data['Engineering Stress 2W']

    eng_stress.add_trace(go.Scatter(x=strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    #eng_stress.add_trace(go.Scatter(x=strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]} 2W", 
                                                        #line=dict(width=3, dash="longdash", color=color[idx])))
    # Customize layout
eng_stress.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="Engineering Stress vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Stress (MPa)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=20, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

eng_stress.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
eng_stress.write_html(os.path.join(fig_path, "eng_stress_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
eng_stress = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['True Stress 1W']
    stress_2w = data['Engineering Stress 2W']

    eng_stress.add_trace(go.Scatter(x=strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    #eng_stress.add_trace(go.Scatter(x=strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]} 2W", 
                                                        #line=dict(width=3, dash="longdash", color=color[idx])))
    # Customize layout
eng_stress.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="True Stress vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Stress (MPa)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=20, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

eng_stress.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)

# Display the interactive plot
eng_stress.write_html(os.path.join(fig_path, "true_stress_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv

# %%
force_interphase = go.Figure()

for idx, file in enumerate(selected):
    print(file)
    data = pd.read_csv(file)
    data.drop(labels='Unnamed: 0', axis=1, inplace=True)
    #print(data.columns)

    strain = data["Time"]
    stress_1w = data['Front Force']
    stress_2w = data['Back Force']

    #force_interphase.add_trace(go.Scatter(x=strain, y=-stress_1w*1000, mode='lines', name=f"{legends[idx]} Front", 
                                                        #line=dict(width=3, dash="solid", color=color[idx])))
    force_interphase.add_trace(go.Scatter(x=strain, y=-stress_2w*1000, mode='lines', name=f"{legends[idx]}", 
                                                        line=dict(width=3, dash=line_mode[idx], color=color[idx])))
    # Customize layout
force_interphase.update_layout(width=1500, height=800, plot_bgcolor="#F5F5F5", paper_bgcolor="#FFFFFF",
                             title=dict(text="Force vs Time", x=0.5, y=0.95, xanchor="center",
                                        font=dict(size=36, color="black", family="Arial")),
                             xaxis=dict(title=dict(text="Time (ms)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridcolor="lightgrey", gridwidth=1),
                             yaxis=dict(title=dict(text="Force (kN)", font=dict(family="Arial", size=24, color="black")),
                                        tickfont=dict(size=24, color="black", family="Arial"), showgrid=True,
                                        gridwidth=1, gridcolor="lightgrey", zeroline=True, zerolinewidth=2, zerolinecolor="grey"),
                             legend=dict(title="Experiment", x=1.0, y=1.0, font=dict(size=16, color="black", family="Arial"),
                                         bgcolor="#FFFFFF", bordercolor="black", borderwidth=2))

force_interphase.add_annotation(
        text=f"Striker Size = 18 in <br>Striker Velocity ~ 25 m/s <br>Incident Stress ~ 500 MPa",
        xref="paper", yref="paper", x=0, y=1, showarrow=False,
        font=dict(size=16, color="black", family="Arial"), align="left", bgcolor="white", bordercolor="black", borderwidth=2)
# Display the interactive plot
force_interphase.write_html(os.path.join(fig_path, "force_study.html"), include_plotlyjs='cdn')
# Out:
# ../results\AL7075T6\AL7075T6_010\AL7075T6_010_secondary_data.csv
# ../results\A356\A356_002\A356_002_secondary_data.csv
# ../results\ST_1018\ST1018_009\ST1018_009_secondary_data.csv
# ../results\SS316_Mono\SS316_002\SS316_002_secondary_data.csv
# ../results\SS316_3D\SS316_009\SS316_009_secondary_data.csv
# ../results\Composites\SS316A356_001\SS316A356_001_secondary_data.csv
